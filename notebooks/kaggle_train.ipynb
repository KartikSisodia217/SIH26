# %% [markdown]
# # OceanEmbed Final Kaggle Training Workflow
#
# This notebook orchestrates the training of ConvFormer on the full multi-year Zarr dataset.

# %%
# !pip install torch numpy xarray zarr

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

# %%
from src.training.config import Config
from src.training.train import train

# Override config for Kaggle if needed
Config.batch_size = 4
Config.num_workers = 4
Config.prefetch_factor = 2

# Note: Mount dataset via Kaggle datasets to /kaggle/input/..., and set Config.inputs_path and targets_path accordingly.

train(dummy_mode=False)
